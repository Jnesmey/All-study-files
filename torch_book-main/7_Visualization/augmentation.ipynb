# %% [markdown]
# # Аугментация mix и сглаженная

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data
import torch.nn.functional as F
import torchvision
from torchvision import transforms
from PIL import Image, ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES=True

# %% [markdown]
# ## Настройка загрузчика данных DataLoaders
#
# Мы будем использовать встроенный набор данных `torchvision.datasets.ImageFolder`, чтобы быстро создать несколько загрузчиков данных загруженных изображений кошек и рыб.
#
# `check_image` - это небольшая функция, которая передается параметру `is_valid_file` в ImageFolder и выполняет проверку на вменяемость, чтобы убедиться, что PIL действительно может открыть файл. Мы будем использовать ее вместо очистки загруженного набора данных.

# %%
def check_image(path):
    try:
        im = Image.open(path)
        return True
    except:
        return False

# %% [markdown]
# Установка трансформации для каждого изображения:
#
# * Ужатие до 64x64
# * Преобразование в тензор
# * Нормализация с использованием параметров ImageNet mean & std

# %%
img_transforms = transforms.Compose([
    transforms.Resize((64,64)),    
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                    std=[0.229, 0.224, 0.225] )
    ])

# %% [markdown]
# ## Распаковка датасета

# %%
# !unzip images
# Out:
# Archive:  images.zip
#    creating: test/
#    creating: test/fish/
#   inflating: test/fish/2242992316_2d999508d6.jpg
#   inflating: test/fish/2163764976_f78d9d0f86.jpg
#   inflating: test/fish/359504247_abafe8992c.jpg
#   inflating: test/fish/578651623_d4cdbc4846.jpg
#   inflating: test/fish/2166804428_663d7a094b.jpg
#   inflating: test/fish/120994748_bf47e3da6d.jpg
#   inflating: test/fish/1332343289_a3a43fafe6.jpg
#   inflating: test/fish/1394413521_27536c0a8f.jpg
#   inflating: test/fish/50081802_bf4d207cd5.jpg
#  extracting: test/fish/silversalmon.jpg
#   inflating: test/fish/3046908845_10016c4dcd.jpg
#   inflating: test/fish/999386881_b6bbc2c39a.jpg
#   inflating: test/fish/7654_1163794241.jpg
#  extracting: test/fish/sctrnbw06_07.jpg
#  extracting: test/fish/dave%20with%20two%20silvers.jpg
#   inflating: test/fish/2561312476_c39a0095c4.jpg
#  extracting: test/fish/Coho%20Salmon%20%20IMG_0970.JPG
#  extracting: test/fish/2919672812_a2deec6048.jpg
#   inflating: test/fish/194363226_2988e58d3b.jpg
#  extracting: test/fish/PB280171.JPG
#   inflating: test/fish/118484640_7a2337ea53.jpg
#  extracting: test/fish/2791981278_00389ecea0.jpg
#   inflating: test/fish/36488930_5d269647b5.jpg
#  extracting: test/fish/1225404080_8048600a94.jpg
#   inflating: test/fish/1406240463_a50c959b4f.jpg
#   inflating: test/fish/2236032554_a9e311b50d.jpg
#   inflating: test/fish/rainbow1.jpg
#   inflating: test/fish/Ace_Charters.jpg
#   inflating: test/fish/1437616227_7a472496c7.jpg
#   inflating: test/fish/35099721_fbc694fa1b.jpg
#  extracting: test/fish/13.jpg
#   inflating: test/fish/517983313_ed34265eeb.jpg
#   inflating: test/fish/2175793957_40fb02bbdb.jpg
#   inflating: test/fish/1609964156_ba06e05149.jpg
#  extracting: test/fish/2638045329_4d8166932d.jpg
#   inflating: test/fish/1430557415_61b31641ca.jpg
#   inflating: test/fish/2969203965_ca49b93d56.jpg
#   inflating: test/fish/980671448_fd2f4503cd.jpg
#   inflating: test/fish/1251878334_a50e0eb93c.jpg
#   inflating: test/fish/ninsilver.jpg
#   inflating: test/fish/3023167383_7ceca252a7.jpg
#   inflating: test/fish/salmon.jpg
#   inflating: test/fish/2402930384_59be26e0c2.jpg
#   inflating: test/fish/41645752_55a91e4bb4.jpg
#   inflating: test/fish/2969215117_074a7a3743.jpg
#   inflating: test/fish/2871258575_b9e311e02a.jpg
#  extracting: test/fish/1061636927_55150f759c.jpg
#   inflating: test/fish/2226705269_0234008814.jpg
#   inflating: test/fish/SteveSilver.jpg
#   inflating: test/fish/2869804396_c4127ccec6.jpg
#   inflating: test/fish/upcoming2.jpg
#   inflating: test/fish/2370449878_5c8baec6bc.jpg
#  extracting: test/fish/171147851_0fa3cc8321.jpg
#   inflating: test/fish/2794928520_0c19eaa483.jpg
#  extracting: test/fish/1155341513_68ffbeb5f5.jpg
#  extracting: test/fish/1140037425_fc25db4d3e.jpg
#   inflating: test/fish/3059250243_897506ffff.jpg
#   inflating: test/fish/silver15.jpg
#  extracting: test/fish/silvers.jpg
#   inflating: test/fish/1378047776_f1405589dd.jpg
#   inflating: test/fish/2960642554_f3e65e5fba.jpg
#   inflating: test/fish/2874145458_c44cd1875a.jpg
#   inflating: test/fish/1798162821_1aa386776e.jpg
#   inflating: test/fish/2401986783_9d8d7475f6.jpg
#   inflating: test/fish/238656308_45fef30371.jpg
#  extracting: test/fish/PNGSsalmon07.jpg
#   inflating: test/fish/191453232_bd89612f16.jpg
#  extracting: test/fish/2791983612_b1ef77c740.jpg
#   inflating: test/fish/revenge05.jpg
#  extracting: test/fish/CSalmon.jpg
#   inflating: test/fish/1096796892_14ad55ba7f.jpg
#   inflating: test/fish/2226705271_0e44f22cf9.jpg
#   inflating: test/fish/1472023781_cd399ebb35.jpg
#   inflating: test/fish/1387629108_1d4f96b12c.jpg
#   inflating: test/fish/1609947018_bfa1fcd6b2.jpg
#   inflating: test/fish/afgsalmon%20boy%20with%20silver.jpg
#   inflating: test/fish/1782114258_8877475e18.jpg
#  extracting: test/fish/1347194721_589b1b7c93.jpg
#   inflating: test/fish/AKS88-409_Alagnak_silver.jpg
#  extracting: test/fish/2021623960_46399ec0ef.jpg
#   inflating: test/fish/wilderness_beach.jpg
#   inflating: test/fish/1572109600_37698877c0.jpg
#   inflating: test/fish/2926283211_a38e806f06.jpg
#   inflating: test/fish/2298715967_d5c00714fe.jpg
#   inflating: test/fish/885829280_0384673c8c.jpg
#   inflating: test/fish/2895832118_e64667d0d6.jpg
#   inflating: test/fish/group_salmon_fishing.jpg
#   inflating: test/fish/226606147_b42e97da41.jpg
#   inflating: test/fish/2457969349_6ebfe30c23.jpg
#  extracting: test/fish/coho.jpg
#   inflating: test/fish/246232021_a806f30fbc.jpg
#   inflating: test/fish/2264748919_f71767086e.jpg
#   inflating: test/fish/1528368520_c82bb63ded.jpg
#   inflating: test/fish/1394607161_290937d216.jpg
#    creating: test/cat/
#   inflating: test/cat/439893681_babdd5ae3d.jpg
#   inflating: test/cat/161008951_c85a3e5128.jpg
#   inflating: test/cat/435628810_a6b6f99454.jpg
#   inflating: test/cat/938480428_de707cc5e3.jpg
#   inflating: test/cat/1745965562_52bcfbc653.jpg
#   inflating: test/cat/803975840_0c65465c81.jpg
#   inflating: test/cat/283032138_3c9a892d25.jpg
#   inflating: test/cat/92019032_a4a5367bb8.jpg
#   inflating: test/cat/504001750_122db89bdb.jpg
#   inflating: test/cat/888742668_33b07f50ac.jpg
#   inflating: test/cat/776126883_5bce88df32.jpg
#   inflating: test/cat/2080082663_44fb124ce0.jpg
#  extracting: test/cat/2219782724_282abe79b7.jpg
#   inflating: test/cat/120259010_5d0791c5fe.jpg
#   inflating: test/cat/6170850_a262e64099.jpg
#   inflating: test/cat/1277930406_89098c53dd.jpg
#   inflating: test/cat/1531265150_52eebb5101.jpg
#   inflating: test/cat/778132371_aabe7d2876.jpg
#   inflating: test/cat/1801833455_88ea90b7d5.jpg
#   inflating: test/cat/428354258_03b6ee38b7.jpg
#   inflating: test/cat/15820790_eb03e0c6fc.jpg
#   inflating: test/cat/2223297783_5a52ccde78.jpg
#   inflating: test/cat/1065639116_70b678b7a2.jpg
#   inflating: test/cat/495308681_e317861b3e.jpg
#   inflating: test/cat/2136995021_2b7d3a6f45.jpg
#   inflating: test/cat/42134688_8fcef55dbf.jpg
#   inflating: test/cat/2114871796_c9ff2992fc.jpg
#   inflating: test/cat/141659362_9f9dfb6782.jpg
#   inflating: test/cat/432509004_574c88c567.jpg
#   inflating: test/cat/2121141374_a7926b616c.jpg
#   inflating: test/cat/185728755_53d16da171.jpg
#   inflating: test/cat/530227296_288d64944f.jpg
#   inflating: test/cat/2053642974_da6791e91f.jpg
#   inflating: test/cat/1083880130_e701a23a0d.jpg
#   inflating: test/cat/2229414874_ed4524d3dd.jpg
#   inflating: test/cat/350588612_d84d71cc59.jpg
#   inflating: test/cat/298845523_84a02f7bac.jpg
#   inflating: test/cat/2130853705_7762d01eae.jpg
#   inflating: test/cat/1130458060_b77117482a.jpg
#   inflating: test/cat/218249723_c0dd3872f6.jpg
#   inflating: test/cat/366292337_d69effc0f7.jpg
#   inflating: test/cat/778267281_8d3e27caa6.jpg
#   inflating: test/cat/522713053_e27cc40632.jpg
#   inflating: test/cat/1511949988_df645b0815.jpg
#   inflating: test/cat/2156521163_f7d45b6f6e.jpg
#   inflating: test/cat/502335523_a27cc49840.jpg
#   inflating: test/cat/2100972415_c4c97d74fe.jpg
#  extracting: test/cat/464580812_9a84a39d97.jpg
#   inflating: test/cat/763072093_f6d4ab4518.jpg
#   inflating: test/cat/964680081_22d67a2416.jpg
#   inflating: test/cat/1731826533_0dd2c03a78.jpg
#   inflating: test/cat/465423833_3a7229f251.jpg
#   inflating: test/cat/2071455892_689f59db15.jpg
#   inflating: test/cat/112682674_9baac5dad3.jpg
#   inflating: test/cat/1382246820_a5f4d43ad0.jpg
#   inflating: test/cat/100970828_a2e6ade482.jpg
#   inflating: test/cat/42226183_a7407e5008.jpg
#  extracting: test/cat/2087049628_381e2034e1.jpg
#   inflating: test/cat/2046753192_b033c7a586.jpg
#   inflating: test/cat/64486923_5e33b6db60.jpg
#  extracting: test/cat/479775027_fbc2e23970.jpg
#   inflating: test/cat/3156111_a9dba42579.jpg
#   inflating: test/cat/2167962061_2f1e3a4398.jpg
#   inflating: test/cat/2223118001_dd20a949f7.jpg
#   inflating: test/cat/77210967_c2dc57e535.jpg
#   inflating: test/cat/304734931_a05b9353a3.jpg
#  extracting: test/cat/498398268_aae3009df3.jpg
#   inflating: test/cat/129440375_9eab70b0fe.jpg
#   inflating: test/cat/2220376711_a5e5ee3d81.jpg
#   inflating: test/cat/300581891_e9a14e195a.jpg
#   inflating: test/cat/338883447_52150d3aab.jpg
#   inflating: test/cat/530294944_83b401cc6a.jpg
#   inflating: test/cat/998182751_c8f59e618e.jpg
#   inflating: test/cat/82177798_43ddc48885.jpg
#   inflating: test/cat/494700298_6d650319d2.jpg
#   inflating: test/cat/324927718_21eaa734ce.jpg
#   inflating: test/cat/1095983024_2ce1dcb2f6.jpg
#   inflating: test/cat/339543799_cc5813505e.jpg
#  extracting: test/cat/16135136_262b1e984d.jpg
#  extracting: test/cat/2115133686_808ce0a5a5.jpg
#  extracting: test/cat/2233999520_1c493de45c.jpg
#   inflating: test/cat/663418041_3f7c77d19a.jpg
#   inflating: test/cat/381333292_addc8df1df.jpg
#   inflating: test/cat/1106795227_e1e24ce29c.jpg
#   inflating: test/cat/261385269_5f0e6578b2.jpg
#   inflating: test/cat/41775356_59e1d64431.jpg
#   inflating: test/cat/1382679537_fef06281a9.jpg
#   inflating: test/cat/2041806579_e4a7f31b32.jpg
#   inflating: test/cat/98705477_fa4d6f1583.jpg
#   inflating: test/cat/527455280_07617e3ffb.jpg
#   inflating: test/cat/2088675755_f68f637f20.jpg
#   inflating: test/cat/2146571469_750ac4c84e.jpg
#   inflating: test/cat/1129508685_d2bf1e70a5.jpg
#   inflating: test/cat/125336040_569fa825b0.jpg
#   inflating: test/cat/1251894244_e30cd194c5.jpg
#   inflating: test/cat/2208405142_cd5801b9de.jpg
#   inflating: test/cat/19599643_8bf721c66a.jpg
#   inflating: test/cat/2046446058_d5e5b2cb61.jpg
#   inflating: test/cat/39573060_d9735440cb.jpg
#   inflating: test/cat/410728656_03daff1602.jpg
#    creating: train/
#    creating: train/fish/
#   inflating: train/fish/54073903_1a1eff74b8.jpg
#   inflating: train/fish/1241328039_ea271fb1ee.jpg
#   inflating: train/fish/118495782_8ee3f0574c.jpg
#   inflating: train/fish/1897299220_b82684a202.jpg
#   inflating: train/fish/717703752_b38872d837.jpg
#   inflating: train/fish/50081584_535979919a.jpg
#   inflating: train/fish/118444107_73f985d0f3.jpg
#   inflating: train/fish/30667866_3e3675f7d5.jpg
#  extracting: train/fish/PicCoho6_small.jpg
#   inflating: train/fish/812568522_137fc69072.jpg
#   inflating: train/fish/2401993715_6f7cf61b09.jpg
#   inflating: train/fish/3933488784_32aaa80087.jpg
#   inflating: train/fish/2742866057_d4656a2d32.jpg
#  extracting: train/fish/1087447360_c6037a47f5.jpg
#   inflating: train/fish/2764146437_87697f1504.jpg
#   inflating: train/fish/675194122_0b0d7e7f36.jpg
#   inflating: train/fish/1535449688_8854addb39.jpg
#   inflating: train/fish/2810840592_fff9c5e4ee.jpg
#   inflating: train/fish/3010626177_f844cb2bd2.jpg
#  extracting: train/fish/dad_king.jpg
#   inflating: train/fish/219291100_8d3b25c845.jpg
#   inflating: train/fish/salmon.gif
#   inflating: train/fish/1991946442_09787de5fe.jpg
#   inflating: train/fish/537924519_74e3ef183b.jpg
#   inflating: train/fish/2777786461_51c3191b59.jpg
#   inflating: train/fish/1973377414_519f350e8b.jpg
#   inflating: train/fish/2974277995_5769c08b9c.jpg
#   inflating: train/fish/1307889110_b1d811d58c.jpg
#   inflating: train/fish/252552297_6ce5c5c08f.jpg
#   inflating: train/fish/2732578142_ec8899e83d.jpg
#   inflating: train/fish/gsilvers.jpg
#   inflating: train/fish/1154501274_773eb0e604.jpg
#   inflating: train/fish/image.jpg
#  extracting: train/fish/IMG_0673-787866.JPG
#  extracting: train/fish/chinook_salmon.jpg
#   inflating: train/fish/2560662749_a101dcd8a8.jpg
#  extracting: train/fish/1348044264_3e0ed6611e.jpg
#   inflating: train/fish/8682840_dd04d1c1e1.jpg
#   inflating: train/fish/50015350_6fb5e1cf9b.jpg
#   inflating: train/fish/226606269_a9e99c18ca.jpg
#   inflating: train/fish/1120626486_256020be45.jpg
#   inflating: train/fish/47925607_705eb202d8.jpg
#  extracting: train/fish/silver2.gif
#   inflating: train/fish/2073982794_24c40e5141.jpg
#   inflating: train/fish/226606581_5529cf1c3d.jpg
#   inflating: train/fish/2695734395_bea8357ec8.jpg
#   inflating: train/fish/228517544_ddbbf8b48b.jpg
#  extracting: train/fish/2021607548_e0835d3552.jpg
#   inflating: train/fish/2500812092_8bea59539d.jpg
#   inflating: train/fish/2536840487_26af971552.jpg
#   inflating: train/fish/1347778917_559f3d6c1c.jpg
#   inflating: train/fish/745712219_781397e6b9.jpg
#   inflating: train/fish/1251018187_4a63d0e545.jpg
#   inflating: train/fish/1792479462_f5cf6a19dd.jpg
#  extracting: train/fish/Silver1.jpg
#   inflating: train/fish/53218001_07651d3afe.jpg
#   inflating: train/fish/2560486437_1884628127.jpg
#   inflating: train/fish/2764988680_cc4c91cd51.jpg
#   inflating: train/fish/219203628_3ccacd75e9.jpg
#   inflating: train/fish/190909220_6195c35877.jpg
#   inflating: train/fish/2828824124_9a85dd3c40.jpg
#   inflating: train/fish/2005116423_315771973a.jpg
#   inflating: train/fish/2046214400_f29df69336.jpg
#   inflating: train/fish/372130289_f00b6a24eb.jpg
#   inflating: train/fish/2561326158_b8835e06bf.jpg
#   inflating: train/fish/1253279817_32245454b1.jpg
#   inflating: train/fish/2916379821_efb5ca6235.jpg
#  extracting: train/fish/silversalmonpic2.jpg
#   inflating: train/fish/310475854_6dbe9c6fd0.jpg
#   inflating: train/fish/1363850921_db239e2272.jpg
#   inflating: train/fish/2906860844_4a4f7f2fed.jpg
#   inflating: train/fish/3839143053_a798f63ec1.jpg
#  extracting: train/fish/233477721_0126cc0331.jpg
#   inflating: train/fish/123556644_412cd0beae.jpg
#   inflating: train/fish/226606160_c9b0edb550.jpg
#  extracting: train/fish/1834276056_4e86bacfe3.jpg
#   inflating: train/fish/MDcohosalmon091203.jpg
#   inflating: train/fish/231668395_9bba46cb44.jpg
#   inflating: train/fish/54035085_2c3c067bae.jpg
#   inflating: train/fish/756819518_a0ab845862.jpg
#  extracting: train/fish/2077711662_c9da691b0a.jpg
#   inflating: train/fish/41645792_684cf4e401.jpg
#   inflating: train/fish/2977999235_13dff038aa.jpg
#   inflating: train/fish/2980180213_4d4299d9f2.jpg
#   inflating: train/fish/2981035546_be0b16c5a3.jpg
#   inflating: train/fish/2079224923_44d216c3e0.jpg
#   inflating: train/fish/1793906015_ef6a88942a.jpg
#   inflating: train/fish/47747356_119d8049c1.jpg
#   inflating: train/fish/2253718801_907f38d8af.jpg
#   inflating: train/fish/327422523_641c6dfab1.jpg
#   inflating: train/fish/121575564_c1385979f8.jpg
#   inflating: train/fish/219297196_b0945405b9.jpg
#   inflating: train/fish/38938964_70986a086f.jpg
#   inflating: train/fish/2041348534_5dc7295a3e.jpg
#   inflating: train/fish/2219052420_4c0ed733a4.jpg
#   inflating: train/fish/1883002210_9f663f97f3.jpg
#   inflating: train/fish/53191895_6f1d32a3d2.jpg
#   inflating: train/fish/874260536_9885356bdf.jpg
#  extracting: train/fish/photos19_med.jpg
#   inflating: train/fish/905990450_3dd52c1e96.jpg
#   inflating: train/fish/53216967_b0038fa2f2.jpg
#  extracting: train/fish/34-8image.jpg
#   inflating: train/fish/2991941039_b3597fd739.jpg
#   inflating: train/fish/47892354_99592df31b.jpg
#   inflating: train/fish/1348668880_a000d9d17a.jpg
#  extracting: train/fish/1879139277_71ea573139.jpg
#   inflating: train/fish/2891759887_cab32f9e3c.jpg
#   inflating: train/fish/2735981970_c5063d535b.jpg
#   inflating: train/fish/1352934868_d7d5b019b8.jpg
#   inflating: train/fish/1793908287_5e6f370b1f.jpg
#   inflating: train/fish/211532038_5bdb5b1bff.jpg
#   inflating: train/fish/2958014099_d00408363e.jpg
#   inflating: train/fish/1333371210_e8b7c99e5d.jpg
#  extracting: train/fish/CohoSalmon_ByErnest%20Keeley.jpg
#   inflating: train/fish/2326716705_4aebb9c2be.jpg
#   inflating: train/fish/258261936_32fb1c62f2.jpg
#   inflating: train/fish/1430252574_f0d02d536e.jpg
#  extracting: train/fish/1833444691_dc3d1017db.jpg
#   inflating: train/fish/2561363748_93412888cc.jpg
#   inflating: train/fish/1455355843_41be181136.jpg
#   inflating: train/fish/2401996649_25a7ffe861.jpg
#   inflating: train/fish/473534567_09c51c7565.jpg
#   inflating: train/fish/118495684_7ccd6e6030.jpg
#   inflating: train/fish/1347770617_bbce95ab66.jpg
#   inflating: train/fish/219203619_ba363f7c65.jpg
#   inflating: train/fish/829357788_035ec8a6d4.jpg
#   inflating: train/fish/2163633271_3387ca02c7.jpg
#   inflating: train/fish/2560653647_d5d0858f92.jpg
#   inflating: train/fish/silver17.jpg
#   inflating: train/fish/3023172427_20630e22ca.jpg
#   inflating: train/fish/2851767032_db42e659d5.jpg
#  extracting: train/fish/2777354896_176a518b8c.jpg
#   inflating: train/fish/431756194_38ef71b2c6.jpg
#   inflating: train/fish/2927004632_b4fe01313d.jpg
#  extracting: train/fish/2886597440_5b3a936f6d.jpg
#   inflating: train/fish/silver_salmon_002.jpg
#   inflating: train/fish/49747515_a0ce300ed8.jpg
#   inflating: train/fish/2969208595_f09750afbd.jpg
#   inflating: train/fish/525607407_a4b90ac834.jpg
#  extracting: train/fish/1242460238_57b66f8072.jpg
#   inflating: train/fish/32438138_54e6c13a55.jpg
#   inflating: train/fish/191453234_00b5443830.jpg
#  extracting: train/fish/521168219_ad61ac2925.jpg
#   inflating: train/fish/2405757805_caa556e94e.jpg
#  extracting: train/fish/2824589595_07ee2443a3.jpg
#  extracting: train/fish/2970698030_1021311f52.jpg
#   inflating: train/fish/1431384312_7443b4dd81.jpg
#   inflating: train/fish/1438308486_86ab656e7d.jpg
#   inflating: train/fish/2494369618_f294b045e5.jpg
#   inflating: train/fish/231427228_88b1105905.jpg
#  extracting: train/fish/1287462891_f1a3e27b50.jpg
#   inflating: train/fish/59220367_0b9a8ba200.jpg
#  extracting: train/fish/917843339_6485bec882.jpg
#   inflating: train/fish/219297194_1e9cbcc205.jpg
#  extracting: train/fish/1956494336_5591fa37da.jpg
#  extracting: train/fish/Ultralight_salmon_fishing_small.jpg
#   inflating: train/fish/37187967_c84b761d8e.jpg
#  extracting: train/fish/1879253211_7ea061692c.jpg
#  extracting: train/fish/3006747829_8658331ecd.jpg
#   inflating: train/fish/228360164_589859e45c.jpg
#  extracting: train/fish/1010685601_0b99c42459.jpg
#   inflating: train/fish/1096801276_d33045c6f6.jpg
#   inflating: train/fish/242011120_bf3e121dc3.jpg
#  extracting: train/fish/2297032796_b5eb52b860.jpg
#   inflating: train/fish/2745192620_072f9c3215.jpg
#  extracting: train/fish/1455910975_07315bf34e.jpg
#  extracting: train/fish/747119762_615603a9a0.jpg
#   inflating: train/fish/118485305_bb0a47ab7c.jpg
#   inflating: train/fish/391465802_e50904b586.jpg
#   inflating: train/fish/2560656203_63fa5a0716.jpg
#   inflating: train/fish/2551526885_8c17d44e23.jpg
#  extracting: train/fish/747122396_3de7f87df3.jpg
#   inflating: train/fish/219297193_87210ea4b2.jpg
#   inflating: train/fish/473533969_ada9207790.jpg
#   inflating: train/fish/2777786883_c7a0194959.jpg
#   inflating: train/fish/32469229_74c9dd84ca.jpg
#   inflating: train/fish/64776504_e012e6af1b.jpg
#   inflating: train/fish/2194115501_ace2dc94f8.jpg
#   inflating: train/fish/316777525_aab1690b4f.jpg
#   inflating: train/fish/2962210096_74b6768926.jpg
#  extracting: train/fish/Picture16.jpg
#   inflating: train/fish/251648189_91da9e97ca.jpg
#   inflating: train/fish/1127389523_0c9446a55f.jpg
#   inflating: train/fish/59220413_2ec8f07c30.jpg
#   inflating: train/fish/2982090768_b4f86cdc8c.jpg
#   inflating: train/fish/62016837_2ca467ff27.jpg
#   inflating: train/fish/2304172273_1c5058c866.jpg
#  extracting: train/fish/silver_salmon_father_son.jpg
#   inflating: train/fish/39976373_9aff650be8.jpg
#  extracting: train/fish/1084292263_542314f2ed.jpg
#  extracting: train/fish/2791982836_fefc141d11.jpg
#  extracting: train/fish/2021603270_2e53566a23.jpg
#  extracting: train/fish/233611459_cc673f6203.jpg
#   inflating: train/fish/1738780429_b574f50528.jpg
#   inflating: train/fish/2801369801_26ab4704fa.jpg
#   inflating: train/fish/293220857_70bae15eba.jpg
#   inflating: train/fish/2371035947_325e2c4811.jpg
#   inflating: train/fish/1408611859_96ec25fbe2.jpg
#   inflating: train/fish/465471271_4af032a44b.jpg
#   inflating: train/fish/2736049296_1342839643.jpg
#   inflating: train/fish/30036526_d098e5b25b.jpg
#   inflating: train/fish/26868895_eeb15da98f.jpg
#   inflating: train/fish/2927004470_07402e25b8.jpg
#   inflating: train/fish/2531962886_0121d2efef.jpg
#   inflating: train/fish/189506304_7219d423fb.jpg
#   inflating: train/fish/2843771253_238e01e1f6.jpg
#   inflating: train/fish/2869927940_56a39186c8.jpg
#  extracting: train/fish/516600404_a300ca8625.jpg
#   inflating: train/fish/2896081148_f1a6ceebb9.jpg
#   inflating: train/fish/2560647753_a732b763e3.jpg
#   inflating: train/fish/fishin22.jpg
#   inflating: train/fish/1320923967_3f90a5723e.jpg
#  extracting: train/fish/727088757_639eb2ccdb.jpg
#  extracting: train/fish/840200833_be72b99848.jpg
#   inflating: train/fish/2926292231_2e6038e605.jpg
#   inflating: train/fish/1792483344_0730b77b72.jpg
#   inflating: train/fish/473539497_5fbe91dc88.jpg
#  extracting: train/fish/3007583030_bd590c07e7.jpg
#  extracting: train/fish/2776496087_1973f8dced.jpg
#   inflating: train/fish/1347769137_ac77144949.jpg
#   inflating: train/fish/2954542105_5d79074a7f.jpg
#   inflating: train/fish/1430671381_2b727d8b9e.jpg
#   inflating: train/fish/329189882_cdcf12e7ed.jpg
#  extracting: train/fish/2483223708_dd90747f10.jpg
#  extracting: train/fish/04%20silver%20salmon%20small.jpg
#   inflating: train/fish/30036983_6acf699f19.jpg
#   inflating: train/fish/1095938485_80b11c5e6d.jpg
#   inflating: train/fish/2659653392_f76786585b.jpg
#   inflating: train/fish/3027122971_5c05827369.jpg
#   inflating: train/fish/2735224527_4ee5534535.jpg
#   inflating: train/fish/269653281_c3fb69a947.jpg
#   inflating: train/fish/1430400153_04236e7e16.jpg
#   inflating: train/fish/2853492613_c6e36df119.jpg
#   inflating: train/fish/2973019314_5bcda4bd11.jpg
#   inflating: train/fish/82241345_9c582454fe.jpg
#   inflating: train/fish/1321809266_35b2951ea2.jpg
#   inflating: train/fish/2940381465_ab4313d02b.jpg
#  extracting: train/fish/248254722_719a163665.jpg
#   inflating: train/fish/235148644_2ab294cdc4.jpg
#   inflating: train/fish/134417007_113594deba.jpg
#   inflating: train/fish/746580832_ded876df16.jpg
#   inflating: train/fish/1332466207_c7f968bc9d.jpg
#   inflating: train/fish/bobmoore.jpg
#   inflating: train/fish/1030154082_dd5461af43.jpg
#   inflating: train/fish/firstcoho.jpg
#   inflating: train/fish/837828962_d145267788.jpg
#  extracting: train/fish/2806314103_c6a27c6a53.jpg
#   inflating: train/fish/2799578576_820a662180.jpg
#  extracting: train/fish/alaskan-salmon.jpg
#   inflating: train/fish/4076334999_c65fb38cae.jpg
#   inflating: train/fish/745721909_54814b76b2.jpg
#   inflating: train/fish/2849329364_4cbfb23baa.jpg
#   inflating: train/fish/2926156887_f0ffd8b301.jpg
#   inflating: train/fish/2304972832_ab2fd510fc.jpg
#   inflating: train/fish/375135916_e5bb539363.jpg
#   inflating: train/fish/2680257507_34e7a27306.jpg
#  extracting: train/fish/2897344494_fa0a244b55.jpg
#   inflating: train/fish/988119351_e53ce19eff.jpg
#  extracting: train/fish/1348034256_cc50f5b446.jpg
#   inflating: train/fish/227516432_431b568340.jpg
#  extracting: train/fish/2807167664_7f0c5891f6.jpg
#   inflating: train/fish/250898049_055bdba422.jpg
#   inflating: train/fish/1386733999_3dbaf2503c.jpg
#   inflating: train/fish/216672026_29775b3680.jpg
#   inflating: train/fish/1609940592_6064e55e66.jpg
#  extracting: train/fish/trophycoho.jpg
#   inflating: train/fish/pasagshakcoho2.jpg
#   inflating: train/fish/2899948086_15bccfa497.jpg
#   inflating: train/fish/2686298442_6e9301c45f.jpg
#   inflating: train/fish/241189633_dd3662953e.jpg
#   inflating: train/fish/2166066189_a0de588b64.jpg
#   inflating: train/fish/126342894_10e76a6718.jpg
#  extracting: train/fish/260564886_6c66708343.jpg
#   inflating: train/fish/226606248_6e59739575.jpg
#  extracting: train/fish/2791131243_7b257bc08b.jpg
#   inflating: train/fish/1878309200_5681ddfbb8.jpg
#   inflating: train/fish/2869102501_fa70e5075d.jpg
#  extracting: train/fish/2667317126_10ee1f1a17.jpg
#   inflating: train/fish/1590828948_3077a1b9de.jpg
#   inflating: train/fish/38939075_7c9c09be12.jpg
#   inflating: train/fish/1904300572_1e36c6049f.jpg
#   inflating: train/fish/366305497_ed332c7c1e.jpg
#   inflating: train/fish/1364739654_fda259c0a4.jpg
#   inflating: train/fish/2096110476_9ffd556a7e.jpg
#   inflating: train/fish/236909006_806c6c7fd9.jpg
#   inflating: train/fish/860969926_708d25e67e.jpg
#   inflating: train/fish/1782113430_eb24eeacda.jpg
#   inflating: train/fish/2198634965_8cd5485517.jpg
#   inflating: train/fish/41645786_a06274e371.jpg
#   inflating: train/fish/255391082_8f0e0938b7.jpg
#   inflating: train/fish/473537859_5c673d6acd.jpg
#   inflating: train/fish/221317903_00ec1a82f8.jpg
#   inflating: train/fish/1609918754_662bb83f2b.jpg
#  extracting: train/fish/deccoho.jpg
#  extracting: train/fish/2662.jpg
#   inflating: train/fish/3042234220_c3941df336.jpg
#   inflating: train/fish/42222930_2bde5135e0.jpg
#   inflating: train/fish/36363495_6bbc6cc891.jpg
#   inflating: train/fish/47747354_8cadae56eb.jpg
#   inflating: train/fish/118484619_7514eee656.jpg
#   inflating: train/fish/2790329208_cb5d9d54a1.jpg
#  extracting: train/fish/2076921635_8146b3766d.jpg
#   inflating: train/fish/463707911_d62a8d585d.jpg
#   inflating: train/fish/230483633_ca6b205540.jpg
#   inflating: train/fish/96433513_bbf9365632.jpg
#  extracting: train/fish/154165958_2428872100.jpg
#   inflating: train/fish/1321811912_36bf77cd8c.jpg
#   inflating: train/fish/1278144041_d46fc8ad13.jpg
#   inflating: train/fish/2959801351_3f7a258f58.jpg
#   inflating: train/fish/2869930096_ffb925c911.jpg
#   inflating: train/fish/2745189412_20af08e56a.jpg
#   inflating: train/fish/2490631048_cd1a254604.jpg
#   inflating: train/fish/3032546380_117ab60107.jpg
#   inflating: train/fish/2555333104_de499e785f.jpg
#   inflating: train/fish/2674771895_30e37f1f52.jpg
#  extracting: train/fish/1140675688_2498ebdcc7.jpg
#   inflating: train/fish/3038428613_b5b23dcaa7.jpg
#   inflating: train/fish/1715956873_77796219a3.jpg
#   inflating: train/fish/2894995479_f72bab9416.jpg
#   inflating: train/fish/2444243335_93f2a37a56.jpg
#  extracting: train/fish/2294965469_d200313929.jpg
#   inflating: train/fish/2927004642_859ac8b6a3.jpg
#   inflating: train/fish/47262196_51796fea66.jpg
#   inflating: train/fish/226606223_f2313f72bd.jpg
#   inflating: train/fish/kingkt.jpg
#   inflating: train/fish/2412522676_500c6eb46c.jpg
#  extracting: train/fish/VInhCoho.jpg
#   inflating: train/fish/2735112385_94bcd85c09.jpg
#   inflating: train/fish/746581990_bdf5769ee4.jpg
#   inflating: train/fish/1386733515_e45a76e27a.jpg
#   inflating: train/fish/2926278479_1e018cb91e.jpg
#   inflating: train/fish/471971306_43e324116c.jpg
#   inflating: train/fish/1478825787_a6a1fd93b3.jpg
#   inflating: train/fish/118495799_68dc1c15ed.jpg
#   inflating: train/fish/1877554840_fe94aaa7d1.jpg
#   inflating: train/fish/198265641_0e60e5300a.jpg
#   inflating: train/fish/2978108677_c08cc6e03d.jpg
#  extracting: train/fish/817922169_08b4a5f740.jpg
#  extracting: train/fish/2806316749_a85a2e1d0f.jpg
#  extracting: train/fish/silver.jpg
#   inflating: train/fish/765459284_b258852b76.jpg
#   inflating: train/fish/image016.jpg
#   inflating: train/fish/2304974372_6528908971.jpg
#   inflating: train/fish/2982226969_539f035ed7.jpg
#   inflating: train/fish/mysilver.jpg
#   inflating: train/fish/366305509_af5ec623ff.jpg
#   inflating: train/fish/4191821586_e9e4c37f48.jpg
#   inflating: train/fish/50021432_654abf2cfc.jpg
#   inflating: train/fish/250233386_5ac442017b.jpg
#   inflating: train/fish/856648463_228b74a8aa.jpg
#   inflating: train/fish/1457976290_f5178f9501.jpg
#   inflating: train/fish/517995651_54be25cbe4.jpg
#   inflating: train/fish/1470840036_127766a09a.jpg
#   inflating: train/fish/97476497_fc30bcea55.jpg
#   inflating: train/fish/219213209_9eb40036c0.jpg
#   inflating: train/fish/1278140797_952c49d1c3.jpg
#   inflating: train/fish/130620683_be00d03c2f.jpg
#  extracting: train/fish/443.guest%20chrome%20silver%20w%20fly.jpg
#   inflating: train/fish/1904302076_12d3cede49.jpg
#   inflating: train/fish/233128326_4c8e98d18a.jpg
#   inflating: train/fish/50081755_283133cfb9.jpg
#  extracting: train/fish/281045869_67c3f5355e.jpg
#   inflating: train/fish/2486650422_2c455730ca.jpg
#   inflating: train/fish/233128382_2b7a432f97.jpg
#   inflating: train/fish/1470082631_085fc17822.jpg
#   inflating: train/fish/119325166_a1ed8b9c57.jpg
#   inflating: train/fish/94494709_1b44a1f550.jpg
#   inflating: train/fish/2661831331_3945d2f6e8.jpg
#  extracting: train/fish/2777353898_99db69973e.jpg
#  extracting: train/fish/1183434487_0de54007df.jpg
#   inflating: train/fish/1241327977_74b2598309.jpg
#   inflating: train/fish/317885000_c0b68ca1d5.jpg
#   inflating: train/fish/1457664051_54192c0932.jpg
#   inflating: train/fish/2561453870_b806f73c34.jpg
#   inflating: train/fish/1357690499_7d30873fed.jpg
#   inflating: train/fish/2705323528_d6a5854f8e.jpg
#   inflating: train/fish/1877554022_4a8fef0aea.jpg
#   inflating: train/fish/2891918807_03d695d527.jpg
#   inflating: train/fish/1307880748_7ef5d625aa.jpg
#   inflating: train/fish/503545659_4408ca5e6b.jpg
#   inflating: train/fish/2149768002_b1d4b0d7b9.jpg
#   inflating: train/fish/218650572_317acd3b81.jpg
#   inflating: train/fish/359498729_9524d64d4a.jpg
#   inflating: train/fish/chum.jpg
#   inflating: train/fish/852198096_d0976c6b53.jpg
#   inflating: train/fish/sc_silver_tsiu_03.jpg
#   inflating: train/fish/250460963_3c88af1b32.jpg
#  extracting: train/fish/2306403424_76da5bb38a.jpg
#  extracting: train/fish/480_Seegraves_nice_silver.jpg
#   inflating: train/fish/311107426_3054bddf7d.jpg
#   inflating: train/fish/2916951063_5904e6edcb.jpg
#   inflating: train/fish/252552309_4a8e8880e7.jpg
#  extracting: train/fish/256085367_30d8e98fa4.jpg
#   inflating: train/fish/1775491925_2ed140f9ba.jpg
#   inflating: train/fish/1243140001_6040003e85.jpg
#   inflating: train/fish/2790333152_11d02d635c.jpg
#   inflating: train/fish/100667576_69fda74c76.jpg
#   inflating: train/fish/310240734_b9c7ba0b18.jpg
#   inflating: train/fish/273635028_64f03c6389.jpg
#   inflating: train/fish/3023976698_46b343b28d.jpg
#   inflating: train/fish/2948099548_c7febce253.jpg
#   inflating: train/fish/391405317_21ef184f6f.jpg
#   inflating: train/fish/921037587_a86277ba85.jpg
#   inflating: train/fish/1332476789_6cdf6a8e56.jpg
#   inflating: train/fish/2735950076_14823c2308.jpg
#  extracting: train/fish/20040808JacobSalmon.jpg
#  extracting: train/fish/2791982160_14b08a4e3c.jpg
#   inflating: train/fish/205154296_c945f19688.jpg
#   inflating: train/fish/50015158_af48418b67.jpg
#   inflating: train/fish/2795782208_8a3e724c25.jpg
#   inflating: train/fish/326775746_38b7fe2ac8.jpg
#   inflating: train/fish/2060299851_7f923be8ec.jpg
#   inflating: train/fish/94150690_d66007ebe2.jpg
#   inflating: train/fish/2560584283_bb90014ba1.jpg
#   inflating: train/fish/3016630693_2651bc2e8a.jpg
#   inflating: train/fish/210183856_b19f050002.jpg
#  extracting: train/fish/2897344310_0cb98bf481.jpg
#   inflating: train/fish/88443784_2876cc92d8.jpg
#   inflating: train/fish/250035490_58d9161506.jpg
#   inflating: train/fish/118485279_dcb3bca6f1.jpg
#   inflating: train/fish/2108952891_858befc9aa.jpg
#  extracting: train/fish/1388069914_0ecc61170d.jpg
#  extracting: train/fish/1278651880_44fe8f9b70.jpg
#   inflating: train/fish/2827774331_0b49ba3ea0.jpg
#   inflating: train/fish/2809758187_b9bed0de16.jpg
#  extracting: train/fish/50021271_c261cd4746.jpg
#   inflating: train/fish/3039276266_6587f552fd.jpg
#   inflating: train/fish/36488532_c55c83d7a4.jpg
#   inflating: train/fish/3015413903_7207770f86.jpg
#   inflating: train/fish/1386734319_15b8cacd6a.jpg
#  extracting: train/fish/dennis.jpg
#  extracting: train/fish/stamp3.gif
#  extracting: train/fish/IMG_4037273.jpg
#   inflating: train/fish/576220992_7d42d6d4eb.jpg
#   inflating: train/fish/1588530027_8df5066aeb.jpg
#   inflating: train/fish/2763824044_14be07e601.jpg
#   inflating: train/fish/428980800_34410f31b5.jpg
#   inflating: train/fish/1607385798_d6d94313d5.jpg
#   inflating: train/fish/1328690550_af16f9b000.jpg
#   inflating: train/fish/311107423_ab4acae592.jpg
#  extracting: train/fish/f43aa33cdff2bbd5e0173ab7a9460f04.jpg
#  extracting: train/fish/PicCoho14_small.jpg
#   inflating: train/fish/201016369_cb81d8eeb3.jpg
#   inflating: train/fish/50021472_5baf5555dd.jpg
#   inflating: train/fish/2560488403_1ac95c8795.jpg
#   inflating: train/fish/273635025_5ca2b872b9.jpg
#  extracting: train/fish/1348098964_4b8c2450e9.jpg
#   inflating: train/fish/1120165084_5ada8a9537.jpg
#   inflating: train/fish/250471088_c1f0b9d1b5.jpg
#  extracting: train/fish/2791133165_5df1d47be5.jpg
#   inflating: train/fish/2720722001_9c561d4329.jpg
#   inflating: train/fish/1609966986_10f4df8253.jpg
#   inflating: train/fish/2927008448_bd65bc10ce.jpg
#   inflating: train/fish/2744377989_020706e206.jpg
#   inflating: train/fish/2982051496_c241ae3b82.jpg
#   inflating: train/fish/1609017629_a3bb518d1c.jpg
#   inflating: train/fish/2840327289_4500dba1ca.jpg
#   inflating: train/fish/2988483435_57d291ca5e.jpg
#   inflating: train/fish/3032536186_96c678cf10.jpg
#   inflating: train/fish/614703650_5493ea4b62.jpg
#   inflating: train/fish/1356959230_861f09dd1e.jpg
#  extracting: train/fish/2734977928_8d16b48c0a.jpg
#  extracting: train/fish/408.jpg
#   inflating: train/fish/2158668659_19e09f3d5e.jpg
#   inflating: train/fish/329189883_2e45e50343.jpg
#   inflating: train/fish/121575464_613abdde53.jpg
#   inflating: train/fish/262268394_2d3532ab50.jpg
#   inflating: train/fish/1386735037_9d1dc598d2.jpg
#   inflating: train/fish/1242063271_c82b45b284.jpg
#  extracting: train/fish/coho.jpg
#  extracting: train/fish/2776494507_7e4cd3a67e.jpg
#   inflating: train/fish/2873238453_a0e67c4fb3.jpg
#   inflating: train/fish/1461209497_d46e710f5b.jpg
#   inflating: train/fish/1715993417_981d7bde8f.jpg
#   inflating: train/fish/2131604094_b2592ae9f4.jpg
#   inflating: train/fish/2095392843_fa8db06a24.jpg
#   inflating: train/fish/473531663_90e6c4d1e4.jpg
#   inflating: train/fish/2871271794_c42695bf42.jpg
#   inflating: train/fish/317199775_8a05c09ed2.jpg
#  extracting: train/fish/1155345869_3f36e2785b.jpg
#  extracting: train/fish/2776498771_20527f258b.jpg
#   inflating: train/fish/219297192_6535ae10c7.jpg
#   inflating: train/fish/1246286612_da8a9a4751.jpg
#   inflating: train/fish/mike&fish.jpg
#   inflating: train/fish/coho_salmon_sm.jpg
#   inflating: train/fish/2879873600_b836c268ba.jpg
#   inflating: train/fish/king1-sm.jpg
#   inflating: train/fish/2991625011_0319cdaee3.jpg
#    creating: train/cat/
#   inflating: train/cat/1285591549_593ca7cf6a.jpg
#   inflating: train/cat/1586410837_b9ce31c2b2.jpg
#   inflating: train/cat/1587917212_cc96feb0ab.jpg
#   inflating: train/cat/1530391249_b310d4b331.jpg
#   inflating: train/cat/161285442_8bcc94a3d5.jpg
#   inflating: train/cat/358940469_786d4c64d7.jpg
#   inflating: train/cat/565727409_61693c5e14.jpg
#   inflating: train/cat/411964593_eda66f129a.jpg
#   inflating: train/cat/216295937_2ad06fb72e.jpg
#   inflating: train/cat/299837288_5c84203463.jpg
#   inflating: train/cat/212787447_54775fb5a1.jpg
#   inflating: train/cat/416625965_f3c3f39cf6.jpg
#   inflating: train/cat/596925517_a05215a375.jpg
#   inflating: train/cat/42134687_2dcbca7ea1.jpg
#   inflating: train/cat/192687065_b97ac2f09e.jpg
#   inflating: train/cat/339533190_9cf17b4d96.jpg
#   inflating: train/cat/762884983_4b9e9f53c3.jpg
#   inflating: train/cat/389105593_354165d41a.jpg
#   inflating: train/cat/178552778_3d8c84d090.jpg
#   inflating: train/cat/1015160097_c4103501de.jpg
#  extracting: train/cat/2103753994_715cd26e9c.jpg
#   inflating: train/cat/1600856989_835664ad28.jpg
#   inflating: train/cat/2080864702_4ed05238fc.jpg
#   inflating: train/cat/331620804_e315322a82.jpg
#   inflating: train/cat/94724274_83d737feec.jpg
#   inflating: train/cat/2088706201_4b434b52f6.jpg
#   inflating: train/cat/53184803_67009002ea.jpg
#   inflating: train/cat/456913874_a4c5dab950.jpg
#   inflating: train/cat/1468792624_3f28670790.jpg
#   inflating: train/cat/371068122_d4278b6bb8.jpg
#   inflating: train/cat/223053154_6ac089b412.jpg
#   inflating: train/cat/1287550918_37c0618cd4.jpg
#   inflating: train/cat/1286961078_102af29059.jpg
#   inflating: train/cat/2204139648_63282de1a4.jpg
#   inflating: train/cat/1737181061_d4391a9627.jpg
#   inflating: train/cat/1140760871_35351b03c5.jpg
#   inflating: train/cat/125127356_4ee7bde116.jpg
#  extracting: train/cat/643693002_6262c7c770.jpg
#   inflating: train/cat/358921562_e25275e771.jpg
#   inflating: train/cat/437477913_bb222deb51.jpg
#   inflating: train/cat/361715964_17ce3f6b18.jpg
#   inflating: train/cat/2221884254_effc37c629.jpg
#   inflating: train/cat/213023529_8d84375b05.jpg
#   inflating: train/cat/371068935_af213116ce.jpg
#   inflating: train/cat/7271769_8e95684683.jpg
#  extracting: train/cat/1516104019_b530c585e4.jpg
#  extracting: train/cat/320793638_f167ca1fc5.jpg
#   inflating: train/cat/525123674_9b6761d7cd.jpg
#   inflating: train/cat/2049593911_a8ab75886b.jpg
#   inflating: train/cat/1641636487_12a2df0642.jpg
#   inflating: train/cat/311234045_257a6f0ce2.jpg
#   inflating: train/cat/596906845_87bd2499df.jpg
#   inflating: train/cat/42584669_6ab87d4ca1.jpg
#   inflating: train/cat/1029412358_7ee17550fc.jpg
#   inflating: train/cat/497844065_b3aab106d6.jpg
#   inflating: train/cat/520524854_bb3e8c99d8.jpg
#   inflating: train/cat/34124450_6995ec9125.jpg
#   inflating: train/cat/2185538257_4623d9f7dd.jpg
#   inflating: train/cat/1175251158_7c9491eb0f.jpg
#   inflating: train/cat/93855106_90048c3e97.jpg
#   inflating: train/cat/128230843_ffc20cb0b9.jpg
#   inflating: train/cat/53001842_6027a96769.jpg
#   inflating: train/cat/416648654_8451c97001.jpg
#   inflating: train/cat/1591151943_db53f18894.jpg
#   inflating: train/cat/1011749488_b465af926a.jpg
#   inflating: train/cat/213052920_a715f92364.jpg
#  extracting: train/cat/522289072_13b4f92d39.jpg
#   inflating: train/cat/1926967076_832ab6ceaa.jpg
#   inflating: train/cat/1458080062_e8120b1c78.jpg
#   inflating: train/cat/230969738_689a138f92.jpg
#   inflating: train/cat/2214498141_79d25c6611.jpg
#   inflating: train/cat/367095400_35a3be47cc.jpg
#   inflating: train/cat/898500300_8cc2a6a0c2.jpg
#   inflating: train/cat/1030251986_4312bc86a9.jpg
#   inflating: train/cat/1074598047_9c49d82aca.jpg
#   inflating: train/cat/450053259_d389c7d9ea.jpg
#   inflating: train/cat/1916815270_9dbc30fa42.jpg
#  extracting: train/cat/2179694251_ef26b307a6.jpg
#   inflating: train/cat/2197815717_ebee4547c4.jpg
#   inflating: train/cat/2221103121_d642f16803.jpg
#   inflating: train/cat/459663559_fee0873e5e.jpg
#   inflating: train/cat/261385585_d43b7b09c3.jpg
#  extracting: train/cat/298022772_916ace8b22.jpg
#   inflating: train/cat/443645811_8c4bb1af50.jpg
#  extracting: train/cat/1541882092_7df1c00498.jpg
#   inflating: train/cat/1181128777_1002ec5d41.jpg
#   inflating: train/cat/40489215_3c98e1b7de.jpg
#   inflating: train/cat/623352147_c30164b0c1.jpg
#   inflating: train/cat/526980964_3f1a6fa364.jpg
#  extracting: train/cat/1011749126_44a195db4c.jpg
#   inflating: train/cat/505539125_d7193beb76.jpg
#   inflating: train/cat/2172322352_72203ff7e9.jpg
#   inflating: train/cat/1609807321_dd3fdba171.jpg
#   inflating: train/cat/255186358_00ab7b74ae.jpg
#  extracting: train/cat/1004525_cba96ba3c3.jpg
#   inflating: train/cat/1484610510_2992aa16bf.jpg
#   inflating: train/cat/1893688733_b941ea93bc.jpg
#   inflating: train/cat/452140439_7c52277e83.jpg
#   inflating: train/cat/464759752_9c09d289fe.jpg
#   inflating: train/cat/110210753_400a37633c.jpg
#   inflating: train/cat/509807655_0be4c6921f.jpg
#   inflating: train/cat/917206849_c44eec3096.jpg
#  extracting: train/cat/75298993_347ab0387c.jpg
#   inflating: train/cat/371070377_7a49bcdcc9.jpg
#   inflating: train/cat/333246955_d4b10135b5.jpg
#   inflating: train/cat/34630974_c6ef06c52c.jpg
#   inflating: train/cat/371071223_2b3bcf06d8.jpg
#   inflating: train/cat/1969450512_ad28bec6a6.jpg
#   inflating: train/cat/189947216_8db2fcab7a.jpg
#   inflating: train/cat/202121902_5dd22d763e.jpg
#   inflating: train/cat/1374093268_a124759f95.jpg
#   inflating: train/cat/525121964_3968192858.jpg
#   inflating: train/cat/433441976_dc6935c8e5.jpg
#   inflating: train/cat/540653104_08e52db275.jpg
#   inflating: train/cat/161027171_e3be4ceddb.jpg
#   inflating: train/cat/493515248_4c3e2780b7.jpg
#   inflating: train/cat/2180889468_b547ae1a5a.jpg
#  extracting: train/cat/359658792_76c6011a76.jpg
#  extracting: train/cat/345925901_d5865b2585.jpg
#   inflating: train/cat/203822627_66cc7c0154.jpg
#   inflating: train/cat/954632637_c5db7fa4d5.jpg
#   inflating: train/cat/512450139_d5befa3160.jpg
#   inflating: train/cat/2000521333_f534d1d702.jpg
#   inflating: train/cat/106818681_88076c6eec.jpg
#   inflating: train/cat/1095526988_7a288676e1.jpg
#   inflating: train/cat/1152574058_7f9278c673.jpg
#   inflating: train/cat/1744125055_dfd0638d6f.jpg
#   inflating: train/cat/164973134_d6799c5db4.jpg
#   inflating: train/cat/2201221380_b8ef18bbcb.jpg
#   inflating: train/cat/133807327_5638ae5eae.jpg
#   inflating: train/cat/516975660_ae33b4b57b.jpg
#  extracting: train/cat/2102976081_61c8614be8.jpg
#   inflating: train/cat/139540076_64446dd631.jpg
#   inflating: train/cat/504313582_57ba5e45cc.jpg
#   inflating: train/cat/2101885301_60bd3d4654.jpg
#   inflating: train/cat/456928459_bad69ac884.jpg
#   inflating: train/cat/339697706_46ef43d3f1.jpg
#   inflating: train/cat/283032077_1d4ee1a1ba.jpg
#  extracting: train/cat/1004527_527c0c32ce.jpg
#   inflating: train/cat/1259825348_6a2aa94e8d.jpg
#   inflating: train/cat/2187709529_637f4b1ea1.jpg
#   inflating: train/cat/278124891_2114f08c99.jpg
#   inflating: train/cat/1097101756_fe209e3a84.jpg
#   inflating: train/cat/1161694367_d513ab417f.jpg
#   inflating: train/cat/67872666_3a1438cca4.jpg
#   inflating: train/cat/88610051_f5358e9d85.jpg
#   inflating: train/cat/1371892048_9e9f3ee318.jpg
#   inflating: train/cat/174732335_7275892317.jpg
#  extracting: train/cat/1171972141_6975842eae.jpg
#   inflating: train/cat/798503612_b64cc21817.jpg
#   inflating: train/cat/2004153940_8fc50ad06a.jpg
#   inflating: train/cat/458865943_58cac7c564.jpg
#   inflating: train/cat/1845262280_b5ba3ffa6f.jpg
#   inflating: train/cat/130028450_3bea7e5120.jpg
#   inflating: train/cat/65048097_e5264bf855.jpg
#   inflating: train/cat/798528274_a5befb1ba6.jpg
#  extracting: train/cat/529556475_2f8a2f8b23.jpg
#   inflating: train/cat/1812521627_5a83110a1c.jpg
#   inflating: train/cat/1241688278_14ca56b240.jpg
#  extracting: train/cat/1011749668_fc48f28767.jpg
#   inflating: train/cat/371068422_47a9b29455.jpg
#   inflating: train/cat/355776256_f05e733a93.jpg
#   inflating: train/cat/98627889_cdb44bd93d.jpg
#   inflating: train/cat/31377472_8b8b15d01b.jpg
#   inflating: train/cat/1181886610_3d23bdc306.jpg
#   inflating: train/cat/1371917878_f0d7937560.jpg
#  extracting: train/cat/290162359_4d481ca788.jpg
#   inflating: train/cat/1907149345_89c10497cc.jpg
#   inflating: train/cat/30402229_d3c45d0b63.jpg
#   inflating: train/cat/2097715605_fe572ee652.jpg
#   inflating: train/cat/25341801_43be0d81fc.jpg
#   inflating: train/cat/276601046_fa141e0f54.jpg
#   inflating: train/cat/202578028_b617c32d6f.jpg
#   inflating: train/cat/341268762_85e6f19f20.jpg
#   inflating: train/cat/649938210_e9dcbde5ea.jpg
#   inflating: train/cat/1137546444_3ddafce68f.jpg
#   inflating: train/cat/131841183_9f01bab747.jpg
#   inflating: train/cat/2095245869_167f4df935.jpg
#   inflating: train/cat/467338710_92e7990f09.jpg
#   inflating: train/cat/123391236_f39d405ba8.jpg
#  extracting: train/cat/416994740_6ada308baa.jpg
#   inflating: train/cat/2088628513_71b9bcdc22.jpg
#  extracting: train/cat/334132664_83e5b5af38.jpg
#   inflating: train/cat/255186483_ed62ee27d8.jpg
#   inflating: train/cat/2183020089_0e0344cd4e.jpg
#   inflating: train/cat/2215772954_e90cf8cd88.jpg
#   inflating: train/cat/1380798923_65eec881a8.jpg
#   inflating: train/cat/352182647_8222f544e5.jpg
#   inflating: train/cat/1561238993_514ec89dc2.jpg
#   inflating: train/cat/466024622_e9c3fa295d.jpg
#   inflating: train/cat/799662943_47a07e43fb.jpg
#   inflating: train/cat/2198300712_453d5a9fb4.jpg
#   inflating: train/cat/132962202_f057174717.jpg
#   inflating: train/cat/2223116765_707032dee7.jpg
#   inflating: train/cat/925773657_640e143da8.jpg
#   inflating: train/cat/1351021942_6449096e65.jpg
#   inflating: train/cat/396186501_265819e97b.jpg
#   inflating: train/cat/345595002_74b5cf3068.jpg
#   inflating: train/cat/262886723_d776213ca3.jpg
#   inflating: train/cat/1371037229_0cf1df9135.jpg
#  extracting: train/cat/709949156_5e4ac3f499.jpg
#   inflating: train/cat/126084132_93e5aeade7.jpg
#  extracting: train/cat/1004528_a111209743.jpg
#   inflating: train/cat/649739480_0491b2db5e.jpg
#   inflating: train/cat/371069587_d70fe0713b.jpg
#   inflating: train/cat/143820538_4337b119d9.jpg
#   inflating: train/cat/2094517433_9761938bbe.jpg
#   inflating: train/cat/464436347_743adfb19e.jpg
#  extracting: train/cat/928732762_eddd8d29af.jpg
#   inflating: train/cat/123580403_4a7dffa10a.jpg
#   inflating: train/cat/1484611144_d589752ffe.jpg
#   inflating: train/cat/57534463_ccc770075a.jpg
#   inflating: train/cat/2135414008_967a7aebdf.jpg
#   inflating: train/cat/70401320_912e4d2d73.jpg
#   inflating: train/cat/441096809_22ee935dc6.jpg
#   inflating: train/cat/965676411_ea7f678902.jpg
#   inflating: train/cat/2532956_1bba28187c.jpg
#   inflating: train/cat/165606472_b162981046.jpg
#   inflating: train/cat/1946817989_3990b900e7.jpg
#   inflating: train/cat/1675734483_4dab1a4cf2.jpg
#   inflating: train/cat/218332367_1fb55e8da9.jpg
#   inflating: train/cat/1901707440_da37ea45b1.jpg
#   inflating: train/cat/1830931077_598deac980.jpg
#   inflating: train/cat/371070650_c528dd7621.jpg
#   inflating: train/cat/955478132_cbd7a7df00.jpg
#   inflating: train/cat/918775832_9ecfd414b8.jpg
#   inflating: train/cat/222767742_1012b9722f.jpg
#   inflating: train/cat/126102069_41456b04bd.jpg
#   inflating: train/cat/1732043533_799114f4b2.jpg
#   inflating: train/cat/129880739_47ef4d064c.jpg
#   inflating: train/cat/2532957_1185565845.jpg
#   inflating: train/cat/508132866_4d69bae597.jpg
#   inflating: train/cat/75714427_07216dd49d.jpg
#   inflating: train/cat/450160344_ebc6c5d6ea.jpg
#   inflating: train/cat/1162408779_6eb2d41a35.jpg
#   inflating: train/cat/846882986_4de328b6b4.jpg
#   inflating: train/cat/511236141_90f36a4960.jpg
#   inflating: train/cat/397934490_2687ae6b71.jpg
#   inflating: train/cat/2181919666_80cabe8d45.jpg
#   inflating: train/cat/57544243_15077074ca.jpg
#   inflating: train/cat/368296176_5b98428fa1.jpg
#   inflating: train/cat/509267567_d69597cfe0.jpg
#   inflating: train/cat/2235269779_6207ea1abd.jpg
#   inflating: train/cat/373046865_16f4c180fe.jpg
#   inflating: train/cat/2134802268_f256811ce5.jpg
#   inflating: train/cat/852161738_902e9d4e24.jpg
#   inflating: train/cat/461684912_034f747f14.jpg
#   inflating: train/cat/235165696_6fe5677fb1.jpg
#   inflating: train/cat/439909665_262dc4a0fe.jpg
#  extracting: train/cat/498439925_56105ec829.jpg
#   inflating: train/cat/213391370_fbc69163e6.jpg
#  extracting: train/cat/1010205192_6ce1a37dc5.jpg
#   inflating: train/cat/597189950_58638188cd.jpg
#   inflating: train/cat/520330558_682540ae3e.jpg
#   inflating: train/cat/1425549611_ee600950f7.jpg
#   inflating: train/cat/1760479467_068432dd3f.jpg
#   inflating: train/cat/256675808_8f1378ed26.jpg
#   inflating: train/cat/255186227_d3cf0ca6e7.jpg
#   inflating: train/cat/10002817_5944408634.jpg
#   inflating: train/cat/597159250_7c93b93b2f.jpg
#   inflating: train/cat/1986619993_4d2e3a5442.jpg
#   inflating: train/cat/530333817_61ed9739f1.jpg
#   inflating: train/cat/416614617_c3b24b70f7.jpg
#   inflating: train/cat/32273118_b2e68f566d.jpg
#   inflating: train/cat/570141189_710601aeb2.jpg
#   inflating: train/cat/276602119_f6e0ed229d.jpg
#   inflating: train/cat/54461669_2791e8f95e.jpg
#   inflating: train/cat/852162860_b4fef593a6.jpg
#   inflating: train/cat/63785988_c16c10b4e5.jpg
#   inflating: train/cat/2088612117_09c208ee23.jpg
#   inflating: train/cat/228831855_3bbae4490c.jpg
#   inflating: train/cat/1284337059_29aaf74695.jpg
#   inflating: train/cat/938629651_33bf85417e.jpg
#   inflating: train/cat/1612667428_4ea558e97b.jpg
#   inflating: train/cat/1210503252_5383fe1c12.jpg
#  extracting: train/cat/5733484_a458450d64.jpg
#   inflating: train/cat/597163670_099446b687.jpg
#   inflating: train/cat/243007380_feda8c8a4c.jpg
#  extracting: train/cat/4193130_a058cdb81f.jpg
#   inflating: train/cat/103392464_9743e196fb.jpg
#   inflating: train/cat/510864988_425996c143.jpg
#   inflating: train/cat/290844103_720b264e6f.jpg
#   inflating: train/cat/635286623_80324c56c1.jpg
#   inflating: train/cat/1844762481_4869ddb7c1.jpg
#   inflating: train/cat/502027704_ef30e4e492.jpg
#   inflating: train/cat/1051238748_e1be3aef35.jpg
#   inflating: train/cat/469376607_5a1f033463.jpg
#   inflating: train/cat/964987618_54ad71ee6e.jpg
#   inflating: train/cat/596887921_3351ff3c15.jpg
#   inflating: train/cat/62347433_f519750764.jpg
#   inflating: train/cat/838925728_5b6e50d797.jpg
#  extracting: train/cat/426029501_9ad83db536.jpg
#   inflating: train/cat/131001499_e6f50809db.jpg
#   inflating: train/cat/55551397_24ad25c8be.jpg
#   inflating: train/cat/327100037_76e397a66f.jpg
#   inflating: train/cat/25341802_95203fb8be.jpg
#   inflating: train/cat/189124128_5878c3e898.jpg
#   inflating: train/cat/2071493754_7f8325b511.jpg
#  extracting: train/cat/100739452_5be2c11557.jpg
#   inflating: train/cat/1579025926_1f9985c3f0.jpg
#   inflating: train/cat/444986815_cdecf4ccc0.jpg
#   inflating: train/cat/2175842690_c25f028f95.jpg
#    creating: val/
#    creating: val/fish/
#  extracting: val/fish/blond_w_silver_small.jpg
#   inflating: val/fish/susannah-coho-wide.jpg
#  extracting: val/fish/pcl10.jpg
#  extracting: val/fish/text-photo-coho1.jpg
#  extracting: val/fish/PicCoho3_small.jpg
#  extracting: val/fish/17.9silverfboshear20oct580x.jpg
#  extracting: val/fish/Lots-of-silver-salmon.jpg
#   inflating: val/fish/265656_f260.jpg
#  extracting: val/fish/silveranchor.jpg
#   inflating: val/fish/fish_cohosalmon_1.jpg
#   inflating: val/fish/Image22.jpg
#  extracting: val/fish/d_with_silver_eyak.jpg
#   inflating: val/fish/79291530.DcwJSUQL.jpg
#  extracting: val/fish/w_salmo_salar1.jpg
#   inflating: val/fish/429838_f520.jpg
#  extracting: val/fish/38.jpg
#  extracting: val/fish/silver3.jpg
#  extracting: val/fish/ni.JPG
#   inflating: val/fish/Smitty-_-Silver-Salmon.jpg
#   inflating: val/fish/AGNEWS_ALASKA.jpg
#   inflating: val/fish/bryan_pradines_silver.jpg
#  extracting: val/fish/silversalmon226at180.jpg
#   inflating: val/fish/coho01.jpg
#  extracting: val/fish/salmon_page.jpg
#  extracting: val/fish/billchar-1wbrdy.jpg
#   inflating: val/fish/salmon.jpg
#  extracting: val/fish/yoksilver.jpg
#  extracting: val/fish/coho_salmon.jpg
#   inflating: val/fish/billdowns2.jpg
#   inflating: val/fish/SteveSilver2_1.jpg
#  extracting: val/fish/20021016_coho.jpg
#   inflating: val/fish/DSCN0326.jpg
#   inflating: val/fish/0a16c110.jpg
#  extracting: val/fish/ryans%20big%20coho.jpg
#   inflating: val/fish/Nov82003Chum_2.jpg
#  extracting: val/fish/200308silver.jpg
#   inflating: val/fish/fish2000_animation2.gif
#  extracting: val/fish/Alaska_08+(16).jpg
#   inflating: val/fish/salmon-4.jpg
#  extracting: val/fish/32462078.bearandlunch.jpg
#  extracting: val/fish/PicCoho10.jpg
#   inflating: val/fish/DSC00663.jpg
#   inflating: val/fish/tg_silver_tsiu_03.jpg
#   inflating: val/fish/head_01.jpg
#   inflating: val/fish/100_1422.JPG
#  extracting: val/fish/salmonsf.jpg
#  extracting: val/fish/conde.jpg
#   inflating: val/fish/salmon4.JPG
#   inflating: val/fish/HPIM1121.JPG
#  extracting: val/fish/bwhiting2.jpg
#   inflating: val/fish/silver_salmon_004.jpg
#  extracting: val/fish/patsy.gif
#   inflating: val/fish/coho.jpg
#  extracting: val/fish/coho-ad-w250.jpg
#   inflating: val/fish/navbl.jpg
#    creating: val/cat/
#   inflating: val/cat/311760015_e0c83a8619.jpg
#   inflating: val/cat/1090859723_50f1dcc9c4.jpg
#   inflating: val/cat/2233444749_1f92c62f5f.jpg
#   inflating: val/cat/527070993_77c53e3222.jpg
#   inflating: val/cat/306406399_f13c110e01.jpg
#   inflating: val/cat/195541676_2949d7cc58.jpg
#   inflating: val/cat/596909911_70b76c309a.jpg
#   inflating: val/cat/439863567_248a675c6d.jpg
#   inflating: val/cat/1041842900_1c5202b05c.jpg
#   inflating: val/cat/1112640457_401418ec93.jpg
#   inflating: val/cat/623149586_d39bf645da.jpg
#   inflating: val/cat/737936987_3873a7ee14.jpg
#   inflating: val/cat/908581714_af7386bb13.jpg
#   inflating: val/cat/223719863_260be6e242.jpg
#   inflating: val/cat/797631309_5408bfa84e.jpg
#   inflating: val/cat/33524095_c9573d494e.jpg
#   inflating: val/cat/2080082253_bdb7b2e4f4.jpg
#   inflating: val/cat/157223424_ea4d801c30.jpg
#   inflating: val/cat/818200588_c865da1bec.jpg
#   inflating: val/cat/54452247_22e1cff358.jpg
#  extracting: val/cat/39351075_8ab1552d3e.jpg
#   inflating: val/cat/126564047_b929724c89.jpg
#   inflating: val/cat/1972050799_f63e09067f.jpg
#   inflating: val/cat/808783922_0086c2de75.jpg
#   inflating: val/cat/807830865_643e54b593.jpg
#   inflating: val/cat/495300082_3154ca61aa.jpg
#   inflating: val/cat/441068932_8915b6de4c.jpg
#  extracting: val/cat/2157560924_19876ea4a2.jpg
#   inflating: val/cat/2142439026_638347bbcd.jpg
#   inflating: val/cat/357584034_3759695ec1.jpg
#   inflating: val/cat/358922730_43d0ab8d2b.jpg
#   inflating: val/cat/107802269_d1ab8f4a81.jpg
#   inflating: val/cat/2219331270_6699b6dfcd.jpg
#   inflating: val/cat/662340663_cd05acf9e8.jpg
#   inflating: val/cat/54453125_ac74c8ba1d.jpg
#   inflating: val/cat/98143589_7b68a681da.jpg
#  extracting: val/cat/57455726_8ccf14753f.jpg
#   inflating: val/cat/347227923_11052bff23.jpg
#   inflating: val/cat/305243094_c72218bdd0.jpg
#   inflating: val/cat/2017893587_55d8632dda.jpg
#   inflating: val/cat/513355862_0542a84fa0.jpg
#   inflating: val/cat/184943010_d0422d720b.jpg
#   inflating: val/cat/520562987_e5a8ca1b73.jpg
#  extracting: val/cat/84450056_bb5974a64f.jpg
#  extracting: val/cat/2206140101_d64a7e3767.jpg
#   inflating: val/cat/846876518_9a9003ce78.jpg
#   inflating: val/cat/171490533_1e91064a8f.jpg
#   inflating: val/cat/2201652923_766bb7a213.jpg
#   inflating: val/cat/457265633_d279d682cf.jpg
#   inflating: val/cat/803975874_457416a7eb.jpg
#   inflating: val/cat/537617436_82e345ce05.jpg
#   inflating: val/cat/114574077_d5167cfc70.jpg
#   inflating: val/cat/262255460_0bb183a463.jpg
#   inflating: val/cat/461691100_5b9d9b1fea.jpg
#   inflating: val/cat/203513295_3a2d83bbc1.jpg
#   inflating: val/cat/1343375875_a912924270.jpg
#   inflating: val/cat/1368039699_fa0b65be65.jpg
#  extracting: val/cat/927881425_8084c41b41.jpg
#  extracting: val/cat/1141687717_890fe14d8e.jpg
#  extracting: val/cat/2151918390_d8c2dc0a62.jpg
#   inflating: val/cat/348423737_92bacd1f57.jpg
#   inflating: val/cat/809663020_7ce9d0899f.jpg
#   inflating: val/cat/2090435515_841c4a1b6a.jpg
#   inflating: val/cat/2177470718_afc06518c6.jpg
#   inflating: val/cat/565212134_50554dda2d.jpg
#   inflating: val/cat/1130279286_f9ce88205a.jpg
#   inflating: val/cat/1555495_bac338b3d1.jpg
#  extracting: val/cat/204035942_de0d323af5.jpg
#   inflating: val/cat/494096831_1ef3925f86.jpg
#   inflating: val/cat/447451822_a71f1d5385.jpg
#   inflating: val/cat/2231206003_461ba2b7b9.jpg
#   inflating: val/cat/1230938727_7eaf8a8718.jpg
#  extracting: val/cat/1323667952_a7a74975c4.jpg
#   inflating: val/cat/1405479296_1881bb5598.jpg
#   inflating: val/cat/143820421_a21d14ab84.jpg
#   inflating: val/cat/436769703_a24a4bc7db.jpg
#   inflating: val/cat/2080864876_00c37bf84b.jpg
#   inflating: val/cat/2221095383_6fb6fff22e.jpg
#   inflating: val/cat/778142671_b39d893f71.jpg
#   inflating: val/cat/389467095_da75cf2cb7.jpg
#   inflating: val/cat/260448163_03c2748acd.jpg
#   inflating: val/cat/504761099_f551dcc330.jpg
#  extracting: val/cat/2102976045_289d3c9471.jpg
#   inflating: val/cat/463035429_34de7fcad7.jpg
#   inflating: val/cat/125161209_fef9585a6a.jpg
#   inflating: val/cat/99029168_940da3a1e5.jpg
#   inflating: val/cat/471573199_68eb6d3714.jpg
#   inflating: val/cat/374626855_8ddc64a19c.jpg
#   inflating: val/cat/917183971_3edd2819c3.jpg
#  extracting: val/cat/426029368_3a9612f006.jpg
#   inflating: val/cat/403770931_228ca9dd3e.jpg
#   inflating: val/cat/1323581252_5cd7421812.jpg
#   inflating: val/cat/891831582_0283187655.jpg
#   inflating: val/cat/97967170_ebd8c6bc5d.jpg
#   inflating: val/cat/155404721_06f2441f3c.jpg
#   inflating: val/cat/249453170_9e8a4bec80.jpg
#   inflating: val/cat/119292984_a34298fd15.jpg
#   inflating: val/cat/431279981_c07df2ca60.jpg
#   inflating: val/cat/404104724_68c501b918.jpg
#   inflating: val/cat/442410088_1da184820c.jpg

# %%
train_data_path = "./train/"
train_data = torchvision.datasets.ImageFolder(root=train_data_path,transform=img_transforms, is_valid_file=check_image)

# %%
val_data_path = "./val/"
val_data = torchvision.datasets.ImageFolder(root=val_data_path,transform=img_transforms, is_valid_file=check_image)

# %%
test_data_path = "./test/"
test_data = torchvision.datasets.ImageFolder(root=test_data_path,transform=img_transforms, is_valid_file=check_image)

# %%
batch_size=64

# %%
train_data_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
val_data_loader  = torch.utils.data.DataLoader(val_data, batch_size=batch_size) 
test_data_loader  = torch.utils.data.DataLoader(test_data, batch_size=batch_size)

# %% [markdown]
# ## Модель нейронной сети

# %%
class CNNNet(nn.Module):

    def __init__(self, num_classes=2):
        super(CNNNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(),
            nn.Linear(4096, num_classes)
        )
    
    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %%
simplenet = CNNNet()

# %% [markdown]
# ## Создаем оптимизатор
#
# Здесь мы просто используем Adam в качестве оптимизатора с коэффициентом обучения 0,001.

# %%
optimizer = optim.Adam(simplenet.parameters(), lr=0.001)

# %% [markdown]
# ## Копирование модели на ГПУ
#
# Копирование модели на ГПУ в случае возможности

# %%
if torch.cuda.is_available():
    device = torch.device("cuda") 
else:
    device = torch.device("cpu")

simplenet.to(device)
# Out:
# CNNNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ## Обучение
#
# Обучаем модель, при необходимости копируя батчи на GPU, рассчитывая потери, оптимизируя сеть и выполняя валидацию для каждой эпохи.

# %%
def train(model, optimizer, loss_fn, train_loader, val_loader, epochs=20, device="cpu"):
    for epoch in range(1, epochs+1):
        training_loss = 0.0
        valid_loss = 0.0
        model.train()
        for batch in train_loader:
            optimizer.zero_grad()
            inputs, targets = batch
            inputs = inputs.to(device)
            targets = targets.to(device)
            output = model(inputs)
            loss = loss_fn(output, targets)
            loss.backward()
            optimizer.step()
            training_loss += loss.data.item() * inputs.size(0)
        training_loss /= len(train_loader.dataset)
        
        model.eval()
        num_correct = 0 
        num_examples = 0
        for batch in val_loader:
            inputs, targets = batch
            inputs = inputs.to(device)
            output = model(inputs)
            targets = targets.to(device)
            loss = loss_fn(output,targets) 
            valid_loss += loss.data.item() * inputs.size(0)
            correct = torch.eq(torch.max(F.softmax(output, dim=1), dim=1)[1], targets)
            num_correct += torch.sum(correct).item()
            num_examples += correct.shape[0]
        valid_loss /= len(val_loader.dataset)

        print('Epoch: {}, Training Loss: {:.2f}, Validation Loss: {:.2f}, accuracy = {:.2f}'.format(epoch, training_loss,
        valid_loss, num_correct / num_examples))

# %%
train(simplenet, optimizer,torch.nn.CrossEntropyLoss(), train_data_loader,val_data_loader, epochs=5, device=device)
# Out:
# Epoch: 1, Training Loss: 1601.95, Validation Loss: 0.72, accuracy = 0.18
# Epoch: 2, Training Loss: 0.71, Validation Loss: 0.73, accuracy = 0.18
# Epoch: 3, Training Loss: 0.67, Validation Loss: 1.00, accuracy = 0.18
# Epoch: 4, Training Loss: 0.78, Validation Loss: 0.74, accuracy = 0.18
# Epoch: 5, Training Loss: 0.69, Validation Loss: 0.79, accuracy = 0.18

# %% [markdown]
# ## Предсказание
#
# Метки располагаются в буквенно-цифровом порядке, поэтому `cat` будет 0, `fish` - 1. Нам понадобится преобразовать изображение, а также убедиться, что полученный тензор скопирован на соответствующее устройство, прежде чем применять к нему нашу модель.

# %%
labels = ['cat','fish']

img = Image.open("./val/cat/1230938727_7eaf8a8718.jpg") 
img = img_transforms(img).to(device)
img = torch.unsqueeze(img, 0)

simplenet.eval()
prediction = F.softmax(simplenet(img), dim=1)
prediction = prediction.argmax()
print(labels[prediction])
# Out:
# fish

# %% [markdown]
# ## Сохранение модели
#
# Мы можем сохранить либо всю модель с помощью save, либо только параметры с помощью state_dict. Последний вариант обычно предпочтительнее, так как позволяет повторно использовать параметры даже при изменении структуры модели (или применять параметры от одной модели к другой).

# %%
torch.save(simplenet, "/tmp/simplenet") 
simplenet = torch.load("/tmp/simplenet")

# %%
torch.save(simplenet.state_dict(), "/tmp/simplenet")    
simplenet = CNNNet()
simplenet_state_dict = torch.load("/tmp/simplenet")
simplenet.load_state_dict(simplenet_state_dict)

# %% [markdown]
# ## mix

# %%
def train(model, optimizer, loss_fn, train_loader, val_loader, epochs=20, device, mix_loader):
  for epoch in range(epochs):
    model.train()
    for batch in zip(train_loader,mix_loader):
      ((inputs, targets),(inputs_mix, targets_mix)) = batch
      optimizer.zero_grad()
      inputs = inputs.to(device)
      targets = targets.to(device)
      inputs_mix = inputs_mix.to(device)
      target_mix = targets_mix.to(device)
      distribution = torch.distributions.beta.Beta(0.5,0.5)
      beta = distribution.expand(torch.zeros(
      batch_size).shape).sample().to(device)
      # Нам нужно преобразовать форму бета, 
      # чтобы она была в тех же размерностях, что и наш входной тензор
      # [batch_size, channels, height, width]
      mixup = beta[:, None, None, None]
      inputs_mixed = (mixup * inputs) + (1-mixup * inputs_mix)
      # Targets are mixed using beta as they have the same shape
      targets_mixed = (beta * targets) + (1-beta * inputs_mix)
      output_mixed = model(inputs_mixed)
      # Умножьте потери на бета и 1-бета, 
      # сложите и получите среднее значение из двух смешанных потерь
      loss = (loss_fn(output, targets) * beta + loss_fn(output, targets_mixed) * (1-beta)).mean()
      # Метод обучения, в обычном режиме, здесь и далее
      loss.backward()
      optimizer.step()

# %% [markdown]
# ## Сглаживание маркировок

# %%
сlass LabelSmoothingCrossEntropyLoss(nn.Module):
  def __init__(self, epsilon=0.1):
    super(LabelSmoothingCrossEntropyLoss, self).__init__()
    self.epsilon = epsilon
    
  def forward(self, output, target):
    num_classes = output.size()[-1]
    log_preds = F.log_softmax(output, dim=-1)
    loss = (-log_preds.sum(dim=-1)).mean()
    nll = F.nll_loss(log_preds, target)
    final_loss = self.epsilon * loss / num_classes + (1-self.epsilon) * nll
    return final_loss
